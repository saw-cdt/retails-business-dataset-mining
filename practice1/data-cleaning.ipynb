# %% [markdown]
# # Data Cleaning

# %% [markdown]
# #### Dataset setup

# %%
import pandas as pd

# %%
df = pd.read_csv('../data/raw/Business_Analytics_Dataset_10000_Rows.csv')
df
# Out:
#       Order_ID Customer_ID  Order_Date Region Product_Category  \
# 0            1    CUST3818  2024-08-18  North         Clothing
# 1            2    CUST9689  2024-06-19  South           Beauty
# 2            3    CUST9147  2024-11-21   West           Sports
# 3            4    CUST7938  2024-07-19  North         Clothing
# 4            5    CUST5127  2024-10-28  South   Home & Kitchen
# ...        ...         ...         ...    ...              ...
# 9995      9996    CUST9137  2024-06-30   West           Beauty
# 9996      9997    CUST3663  2024-08-21   East         Clothing
# 9997      9998    CUST2546  2024-04-05  South         Clothing
# 9998      9999    CUST9750  2024-05-13   East           Sports
# 9999     10000    CUST8377  2024-06-12  North      Electronics
#
#      Customer_Segment  Quantity  Unit_Price  Discount_Rate  Revenue     Cost  \
# 0           Corporate         5      300.68           0.27  1097.48   768.29
# 1         Home Office         9       32.89           0.02   290.09   179.33
# 2           Corporate         5      345.61           0.25  1296.04  1022.60
# 3            Consumer         1      444.50           0.06   417.83   280.99
# 4            Consumer         5       65.13           0.21   257.26   151.90
# ...               ...       ...         ...            ...      ...      ...
# 9995      Home Office         3      210.14           0.09   573.68   422.90
# 9996      Home Office         3      332.67           0.13   868.27   544.27
# 9997        Corporate         5      440.10           0.01  2178.49  1464.86
# 9998      Home Office        10      303.63           0.17  2520.13  1455.60
# 9999         Consumer         8      423.22           0.30  2370.03  1831.04
#
#        Profit    Payment_Method
# 0      329.19       Credit Card
# 1      110.76        Debit Card
# 2      273.44       Credit Card
# 3      136.84               UPI
# 4      105.36       Credit Card
# ...       ...               ...
# 9995   150.78       Credit Card
# 9996   324.00       Credit Card
# 9997   713.63       Net Banking
# 9998  1064.53  Cash on Delivery
# 9999   538.99       Net Banking
#
# [10000 rows x 13 columns]

# %% [markdown]
# #### Dataset info

# %%
print(f"rows: {df.shape[0]}")
# Out:
# rows 10000

# %%
print(f"columns: {df.shape[1]}")
df.columns.tolist()
# Out:
# columns: 12
# ['Customer_ID',
#  'Order_Date',
#  'Region',
#  'Product_Category',
#  'Customer_Segment',
#  'Quantity',
#  'Unit_Price',
#  'Discount_Rate',
#  'Revenue',
#  'Cost',
#  'Profit',
#  'Payment_Method']

# %% [markdown]
# #### Look for missing values

# %%
missing = df.isnull().sum()
if missing.sum() == 0:
    print("No missing values")
else: 
    print(missing[missing > 0])
# Out:
# No missing values

# %% [markdown]
# #### Look for duplicates

# %%
dups = df.duplicated().sum()
if dups == 0:
    print("No duplicated values")
else:
    print(dups)
# Out:
# No duplicated values

# %% [markdown]
# #### Look for negatives

# %%
cols = ['Quantity', 'Unit_Price', 'Revenue', 'Cost', 'Profit']
for col in cols:
    negatives = (df[col] < 0).sum()
    if negatives == 0:
        print(f"No negative values in {col}")
    else:
        print(f"{col}: {negatives} negatives")
# Out:
# No negative values in Quantity
# No negative values in Unit_Price
# No negative values in Revenue
# No negative values in Cost
# No negative values in Profit

# %% [markdown]
# #### Check Discount_rate values

# %%
invalid = ((df['Discount_Rate'] < 0) | (df['Discount_Rate'] > 1)).sum()
if invalid == 0:
    print("All discount rates are valid")
else:
    print(f"{invalid} values outside valid range")
# Out:
# All discount rates are valid

# %% [markdown]
# #### Check Profit

# %%
# Profit = Revenue - Cost
# We use 0.01 as a tolerance
invalid_profit = (abs(df['Profit'] - (df['Revenue'] - df['Cost'])) > 0.01).sum()

if invalid_profit == 0:
    print("All Profit values are valid")
else:
    print(f"{invalid_profit} rows have unvalid values")
# Out:
# All Profit values are valid

# %% [markdown]
# #### Check Revenue

# %%
# Revenue = Quantity × Unit_Price × (1 - Discount_Rate)
# We use 0.01 as a tolerance 
invalid_revenue = (abs(df['Revenue'] - (df['Quantity'] * df['Unit_Price'] * (1 - df['Discount_Rate']))) > 0.01).sum()

if invalid_revenue == 0:
    print("All Revenue values are valid")
else:
    print(f"{invalid_revenue} rows have unvalid values")
# Out:
# All Revenue values are valid

# %% [markdown]
# #### As we can see our data set is almost clean by default, so we just need to modify some small things

# %% [markdown]
# #### Drop unnecesary columns

# %%
df = df.drop(columns = "Order_ID")
df
# Out:
#      Customer_ID  Order_Date Region Product_Category Customer_Segment  \
# 0       CUST3818  2024-08-18  North         Clothing        Corporate
# 1       CUST9689  2024-06-19  South           Beauty      Home Office
# 2       CUST9147  2024-11-21   West           Sports        Corporate
# 3       CUST7938  2024-07-19  North         Clothing         Consumer
# 4       CUST5127  2024-10-28  South   Home & Kitchen         Consumer
# ...          ...         ...    ...              ...              ...
# 9995    CUST9137  2024-06-30   West           Beauty      Home Office
# 9996    CUST3663  2024-08-21   East         Clothing      Home Office
# 9997    CUST2546  2024-04-05  South         Clothing        Corporate
# 9998    CUST9750  2024-05-13   East           Sports      Home Office
# 9999    CUST8377  2024-06-12  North      Electronics         Consumer
#
#       Quantity  Unit_Price  Discount_Rate  Revenue     Cost   Profit  \
# 0            5      300.68           0.27  1097.48   768.29   329.19
# 1            9       32.89           0.02   290.09   179.33   110.76
# 2            5      345.61           0.25  1296.04  1022.60   273.44
# 3            1      444.50           0.06   417.83   280.99   136.84
# 4            5       65.13           0.21   257.26   151.90   105.36
# ...        ...         ...            ...      ...      ...      ...
# 9995         3      210.14           0.09   573.68   422.90   150.78
# 9996         3      332.67           0.13   868.27   544.27   324.00
# 9997         5      440.10           0.01  2178.49  1464.86   713.63
# 9998        10      303.63           0.17  2520.13  1455.60  1064.53
# 9999         8      423.22           0.30  2370.03  1831.04   538.99
#
#         Payment_Method
# 0          Credit Card
# 1           Debit Card
# 2          Credit Card
# 3                  UPI
# 4          Credit Card
# ...                ...
# 9995       Credit Card
# 9996       Credit Card
# 9997       Net Banking
# 9998  Cash on Delivery
# 9999       Net Banking
#
# [10000 rows x 12 columns]

# %% [markdown]
# #### Change Order_Date to datetime

# %%
# Order date is a String
df['Order_Date'].dtype
# Out:
# <StringDtype(storage='python', na_value=nan)>

# %%
# Convert it to datetime
df['Order_Date'] = pd.to_datetime(df['Order_Date'])
df['Order_Date'].dtype
# Out:
# dtype('<M8[us]')

# %% [markdown]
# #### Save the clean dataset

# %%
df_clean = df.copy()
# This one is gonna be for the practice 1 folder
df_clean.to_csv('data_clean.csv', index=False)
# and Im gonna create another one to save it in data folder
df_clean.to_csv('../data/processed/data_clean.csv', index=False)
